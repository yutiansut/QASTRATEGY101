# %% [markdown]
# # S001 King Keltner
#
# King Keltner 策略是基于移动平均线创立的, 基本思想是 在由最高价, 最低价, 收盘价得出的中心价格基础上计算出市场价格通道线的上下轨, 当价格上穿上轨时做多, 下穿下轨时做空, 由于不是每一次突破都会成功, 因此, 合理的止损设置显得尤为重要, 在kk策略中, 选择中心价格作为出场信号
#
# 1. 计算中心价 MP = 最高价, 最低价, 收盘价三者平均后的40周期移动平均价
#
# MP = MA((high+low+close/3), 40)
#
#
# 2. 计算真实价格区间 TrueRange
#
# TR =  max( abs(high_t - low_t), abs(high_t- close_t-1), abs(low_t - close_t-1))
#
# 3. 计算通道上下轨 (upBand, dnBand), 其中mu是一个可变参数, 默认为1
#
# upBand = MP + mu*MA(TR, 40)
#
# dnBand = MP + mu*MA(TR, 40)
#
# 4. 计算平仓价格
#
# FP = MP = MA((high+low+close/3), 40)
#
# 5. 开平仓条件
#
# 买入开仓 BUY_OPEN : 当前周期MP > 上一个周期的MP  AND 当前价格 > upBand
#
# 卖出开仓 SELL_OPEN:  当前周期MP < 上一个周期的MP  AND 当前价格 < upBand
#
# 平仓 : 当前周期价格 下穿  平仓价格FP
#
# 平仓 : 当前周期价格 上穿  平仓价格FP
#
# 平仓既是止盈 也是止损条件
#
#
# 策略简单描述到此, 下面进入分析和策略代码部分

# %%
import QUANTAXIS as QA

# %%
N = 40
mu = 1

# %%
import pandas as pd
def strategy001(data, N=40, mu=1):
    MP = QA.MA((data.high+data.low+data.close)/3, N)
    TR = pd.concat([abs(data.high - data.low), abs(data.high- data.close.shift(1)), abs(data.low - data.close.shift(1))],axis=1).max(axis=1)
    upBand = MP + mu*QA.MA(TR, N)
    dnBand = MP + mu*QA.MA(TR, 40)
    FP = MP
    return pd.DataFrame({'MP': MP, 'TR': TR, 'upBand': upBand, 'dnBand':dnBand, 'FP':MP})

# %% [markdown]
# ## 灌入数据

# %%
data = QA.QA_fetch_future_day_adv("RBL8", '2018-05-01', '2019-09-10')

# %%
data
# Out:
# < QA_DataStruct_Future_day with 1 securities >

# %%
ind = data.add_func(strategy001)

# %%
print(ind.tail())
# Out:
#                           MP    TR       upBand       dnBand           FP
# date       code
# 2019-08-16 RBL8  3906.600000  41.0  3984.725000  3984.725000  3906.600000
# 2019-08-19 RBL8  3902.375000  55.0  3978.600000  3978.600000  3902.375000
# 2019-08-20 RBL8  3896.141667  71.0  3971.766667  3971.766667  3896.141667
# 2019-08-21 RBL8  3888.258333  79.0  3964.683333  3964.683333  3888.258333
# 2019-08-22 RBL8  3879.983333  61.0  3955.233333  3955.233333  3879.983333

# %% [markdown]
# ## 实现策略

# %%
MPDIFF = ind.MP.diff().dropna()

# %%
# 在测试阶段, 我们只需要写个伪回测代码即可

# %%
lastprice = 0

for idx, item in data.iterrows():
    try:
        if MPDIFF.loc[idx]>0 and item['close']> ind.upBand.loc[idx]:
            print('buyOPEN _ {}'.format(idx))
        if MPDIFF.loc[idx]<0 and item['close']< ind.upBand.loc[idx]:
            print('sellOPEN_ {}'.format(idx))
        if lastprice< ind.FP.loc[idx] and item['close']> ind.FP.loc[idx]:
            print('close')
        if lastprice> ind.FP.loc[idx] and item['close']< ind.FP.loc[idx]:
            print('close')
    except:
        pass
    lastprice = item['close']
# Out:
# close
# buyOPEN _ (Timestamp('2018-06-29 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('
00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-08 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-12 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-13 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-14 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-18 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-03-19 00:00:00'), 'RBL8')
# close
# close
# sellOPEN_ (Timestamp('2019-04-01 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-04-02 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-04-03 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-04-04 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-04-08 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-04-09 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-04-10 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-04-11 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-04-15 00:00:00'), 'RBL8')
# close
# close
# close
# sellOPEN_ (Timestamp('2019-04-26 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-04-29 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-06 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-05-08 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-09 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-13 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-14 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-05-15 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-05-16 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-17 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-05-20 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-21 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-22 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-23 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-24 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-27 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-28 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-05-29 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-10 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-13 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-06-14 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-17 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-06-18 00:00:00'), 'RBL8')
# close
# close
# buyOPEN _ (Timestamp('2019-06-21 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-06-24 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-06-25 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-06-26 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-06-27 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-06-28 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-01 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-02 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-03 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-04 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-05 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-08 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-09 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-10 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-11 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-12 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-15 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-16 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-17 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-18 00:00:00'), 'RBL8')
# buyOPEN _ (Timestamp('2019-07-19 00:00:00'), 'RBL8')
# close
# close
# close
# sellOPEN_ (Timestamp('2019-08-06 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-07 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-08 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-09 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-12 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-13 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-14 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-15 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-16 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-19 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-20 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-21 00:00:00'), 'RBL8')
# sellOPEN_ (Timestamp('2019-08-22 00:00:00'), 'RBL8')

# %% [markdown]
# ## 回测代码

# %%
user = QA.QA_User(username='quantaxis', password='quantaxis')
portfolio = user.new_portfolio('strategy101')
# Out:
#  prortfolio with user_cookie  USER_MkAQWd3E  already exist!!

# %%
acc = portfolio.new_account(account_cookie='acc001', init_hold={'RBL8':0}, init_cash=30000, market_type=QA.MARKET_TYPE.FUTURE_CN)
lastprice = 0

for idx, item in data.iterrows():
    try:
        if acc.hold_available.get(idx[1],0) ==0 and MPDIFF.loc[idx]>0 and item['close']> ind.upBand.loc[idx]:
            print('buyOPEN _ {}'.format(idx))
            acc.receive_simpledeal(
                code= idx[1],
                trade_price = item['close'],
                trade_amount = 1,
                trade_towards= QA.ORDER_DIRECTION.BUY_OPEN,
                trade_time= idx[0])
        if acc.hold_available.get(idx[1],0) ==0 and MPDIFF.loc[idx]<0 and item['close']< ind.upBand.loc[idx]:
            print('sellOPEN_ {}'.format(idx))
            acc.receive_simpledeal(
                code= idx[1],
                trade_price = item['close'],
                trade_amount = 1,
                trade_towards= QA.ORDER_DIRECTION.SELL_OPEN,
                trade_time= idx[0])
        if lastprice< ind.FP.loc[idx] and item['close']> ind.FP.loc[idx]:
            print('close')
            if acc.hold_available.get(idx[1],0)>0:
                #多单止盈
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.SELL_CLOSE,
                    trade_time= idx[0])
            elif acc.hold_available.get(idx[1],0)<0:
                # 空单止损
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.BUY_CLOSE,
                    trade_time= idx[0])
                
        if lastprice> ind.FP.loc[idx] and item['close']< ind.FP.loc[idx]:
            print('close')
            if acc.hold_available.get(idx[1],0)>0:
                #多单止损
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.SELL_CLOSE,
                    trade_time= idx[0])
            elif acc.hold_available.get(idx[1],0)<0:
                # 空单止盈
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.BUY_CLOSE,
                    trade_time= idx[0])
    except:
        pass
    lastprice = item['close']
# Out:
# close
# buyOPEN _ (Timestamp('2018-06-29 00:00:00'), 'RBL8')
# close
# close
# buyOPEN _ (Timestamp('2018-09-10 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2018-09-25 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2018-10-18 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2018-10-19 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2018-10-23 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2018-11-02 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-01-09 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-01-10 00:00:00'), 'RBL8')
# close
# close
# sellOPEN_ (Timestamp('2019-04-01 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-04-02 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-04-09 00:00:00'), 'RBL8')
# close
# close
# close
# sellOPEN_ (Timestamp('2019-04-26 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-06 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-09 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-13 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-14 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-05-17 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-10 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-13 00:00:00'), 'RBL8')
# close
# sellOPEN_ (Timestamp('2019-06-17 00:00:00'), 'RBL8')
# close
# close
# buyOPEN _ (Timestamp('2019-06-21 00:00:00'), 'RBL8')
# close
# close
# close
# sellOPEN_ (Timestamp('2019-08-06 00:00:00'), 'RBL8')

# %%
acc.history_table
# Out:
#                datetime  code   price  amount       cash order_id  \
# 0   2018-06-29 00:00:00  RBL8  3807.0       1  26569.893     None
# 1   2018-08-30 00:00:00  RBL8  4118.0      -1  33102.075     None
# 2   2018-09-10 00:00:00  RBL8  4284.0       1  29242.191     None
# 3   2018-09-11 00:00:00  RBL8  4071.0      -1  30963.720     None
# 4   2018-09-25 00:00:00  RBL8  4060.0      -1  27305.660     None
# 5   2018-10-17 00:00:00  RBL8  4197.0       1  29585.463     None
# 6   2018-10-18 00:00:00  RBL8  4108.0      -1  25884.155     None
# 7   2018-10-18 00:00:00  RBL8  4108.0       1  29577.247     None
# 8   2018-10-19 00:00:00  RBL8  4055.0      -1  25923.692     None
# 9   2018-10-22 00:00:00  RBL8  4154.0       1  28579.038     None
# 10  2018-10-23 00:00:00  RBL8  4142.0      -1  24847.096     None
# 11  2018-11-01 00:00:00  RBL8  4057.0       1  29420.839     None
# 12  2018-11-02 00:00:00  RBL8  4064.0      -1  25759.175     None
# 13  2019-01-08 00:00:00  RBL8  3505.0       1  35003.270     None
# 14  2019-01-09 00:00:00  RBL8  3507.0      -1  31843.463     None
# 15  2019-01-09 00:00:00  RBL8  3507.0       1  34996.256     None
# 16  2019-01-10 00:00:00  RBL8  3514.0      -1  31830.142     None
# 17  2019-03-25 00:00:00  RBL8  3692.0       1  33209.050     None
# 18  2019-04-01 00:00:00  RBL8  3497.0      -1  30058.253     None
# 19  2019-04-01 00:00:00  RBL8  3497.0       1  33202.056     None
# 20  2019-04-02 00:00:00  RBL8  3560.0      -1  29994.496     None
# 21  2019-04-08 00:00:00  RBL8  3730.0       1  31494.766     None
# 22  2019-04-09 00:00:00  RBL8  3757.0      -1  28109.709     None
# 23  2019-04-18 00:00:00  RBL8  3710.0       1  31957.299     None
# 24  2019-04-26 00:00:00  RBL8  3739.0      -1  28588.460     None
# 25  2019-04-29 00:00:00  RBL8  3777.0       1  31569.783     None
# 26  2019-05-06 00:00:00  RBL8  3756.0      -1  28185.627     None
# 27  2019-05-08 00:00:00  RBL8  3731.0       1  31812.296     None
# 28  2019-05-09 00:00:00  RBL8  3737.0      -1  28445.259     None
# 29  2019-05-10 00:00:00  RBL8  3746.0       1  31714.813     None
# 30  2019-05-13 00:00:00  RBL8  3691.0      -1  28389.222     None
# 31  2019-05-13 00:00:00  RBL8  3691.0       1  31707.431     None
# 32  2019-05-14 00:00:00  RBL8  3663.0      -1  28407.068     None
# 33  2019-05-16 00:00:00  RBL8  3742.0       1  30910.026     None
#
#     direction  total_frozen
# 0           2        3426.3
# 1          -3           0.0
# 2           2        3855.6
# 3          -3           0.0
# 4          -2        3654.0
# 5           3           0.0
# 6          -2        3697.2
# 7           3           0.0
# 8          -2        3649.5
# 9           3           0.0
# 10         -2        3727.8
# 11          3           0.0
# 12         -2        3657.6
# 13          3           0.0
# 14         -2        3156.3
# 15          3           0.0
# 16         -2        3162.6
# 17          3           0.0
# 18         -2        3147.3
# 19          3           0.0
# 20         -2        3204.0
# 21          3           0.0
# 22         -2        3381.3
# 23          3           0.0
# 24         -2        3365.1
# 25          3           0.0
# 26         -2        3380.4
# 27          3           0.0
# 28         -2        3363.3
# 29          3           0.0
# 30         -2        3321.9
# 31          3           0.0
# 32         -2        3296.7
# 33          3           0.0
# 34         -2        3393.9
# 35          3           0.0
# 36         -2        3345.3
# 37          3           0.0
# 38         -2        3412.8
# 39          3           0.0
# 40         -2        3333.6
# 41          3           0.0
# 42          2        3473.1
# 43         -3           0.0
# 44         -2        3336.3

# %%
performance = QA.QA_Performance(acc)

# %%
performance.pnl_fifo
# Out:
#       sell_date   buy_date  amount  sell_price  buy_price rawdirection  unit  \
# code
# RBL8 2018-08-30 2018-06-29       1      4118.0     3807.0          buy    10
# RBL8 2018-09-11 2018-09-10       1      4071.0     4284.0          buy    10
# RBL8 2018-09-25 2018-10-17       1      4060.0     4197.0         sell    10
# RBL8 2018-10-18 2018-10-18       1      4108.0     4108.0         sell    10
# RBL8 2018-10-19 2018-10-22       1      4055.0     4154.0         sell    10
# RBL8 2018-10-23 2018-11-01       1      4142.0     4057.0         sell    10
# RBL8 2018-11-02 2019-01-08       1      4064.0     3505.0         sell    10
# RBL8 2019-01-09 2019-01-09       1      3507.0     3507.0         sell    10
# RBL8 2019-01-10 2019-03-25       1      3514.0     3692.0         sell    10
# RBL8 2019-04-01 2019-04-01       1      3497.0     3497.0         sell    10
# RBL8 2019-04-02 2019-04-08       1      3560.0     3730.0         sell    10
# RBL8 2019-04-09 2019-04-18       1      3757.0     3710.0         sell    10
# RBL8 2019-04-26 2019-04-29       1      3739.0     3777.0         sell    10
# RBL8 2019-05-06 2019-05-08       1      3756.0     3731.0         sell    10
# RBL8 2019-05-09 2019-05-10       1      3737.0     3746.0         sell    10
# RBL8 2019-05-13 2019-05-13       1      3691.0     3691.0         sell    10
# RBL8 2019-05-14 2019-05-16       1      3663.0     3742.0         sell    10
# RBL8 2019-05-17 2019-05-31       1      3771.0     3750.0         sell    10
# RBL8 2019-06-10 2019-06-11       1      3717.0     3833.0         sell    10
# RBL8 2019-06-13 2019-06-14       1      3792.0     3755.0         sell    10
# RBL8 2019-06-17 2019-06-19       1      3704.0     3770.0         sell    10
# RBL8 2019-07-24 2019-06-21       1      3899.0     3859.0          buy    10
#
#       pnl_ratio  pnl_money hold_gap  if_buyopen  openprice  \
# code
# RBL8   0.081692     3110.0  62 days        True     3807.0
# RBL8  -0.049720    -2130.0   1 days        True     4284.0
# RBL8  -0.032642    -1370.0  22 days       False     4060.0
# RBL8   0.000000        0.0   0 days       False     4108.0
# RBL8  -0.023832     -990.0   3 days       False     4055.0
# RBL8   0.020951      850.0   9 days       False     4142.0
# RBL8   0.159486     5590.0  67 days       False     4064.0
# RBL8   0.000000        0.0   0 days       False     3507.0
# RBL8  -0.048212    -1780.0  74 days       False     3514.0
# RBL8   0.000000        0.0   0 days       False     3497.0
# RBL8  -0.045576    -1700.0   6 days       False     3560.0
# RBL8   0.012668      470.0   9 days       False     3757.0
# RBL8  -0.010061     -380.0   3 days       False     3739.0
# RBL8   0.006701      250.0   2 days       False     3756.0
# RBL8  -0.002403      -90.0   1 days       False     3737.0
# RBL8   0.000000        0.0   0 days       False     3691.0
# RBL8  -0.021112     -790.0   2 days       False     3663.0
# RBL8   0.005600      210.0  14 days       False     3771.0
# RBL8  -0.030264    -1160.0   1 days       False     3717.0
# RBL8   0.009854      370.0   1 days       False     3792.0
# RBL8  -0.017507     -660.0   2 days       False     3704.0
# RBL8   0.010365      400.0  33 days        True     3859.0
#
#                  opendate  closeprice            closedate
# code
# RBL8  2018-06-29 00:00:00      4118.0  2018-08-30 00:00:00
# RBL8  2018-09-10 00:00:00      4071.0  2018-09-11 00:00:00
# RBL8  2018-09-25 00:00:00      4197.0  2018-10-17 00:00:00
# RBL8  2018-10-18 00:00:00      4108.0  2018-10-18 00:00:00
# RBL8  2018-10-19 00:00:00      4154.0  2018-10-22 00:00:00
# RBL8  2018-10-23 00:00:00      4057.0  2018-11-01 00:00:00
# RBL8  2018-11-02 00:00:00      3505.0  2019-01-08 00:00:00
# RBL8  2019-01-09 00:00:00      3507.0  2019-01-09 00:00:00
# RBL8  2019-01-10 00:00:00      3692.0  2019-03-25 00:00:00
# RBL8  2019-04-01 00:00:00      3497.0  2019-04-01 00:00:00
# RBL8  2019-04-02 00:00:00      3730.0  2019-04-08 00:00:00
# RBL8  2019-04-09 00:00:00      3710.0  2019-04-18 00:00:00
# RBL8  2019-04-26 00:00:00      3777.0  2019-04-29 00:00:00
# RBL8  2019-05-06 00:00:00      3731.0  2019-05-08 00:00:00
# RBL8  2019-05-09 00:00:00      3746.0  2019-05-10 00:00:00
# RBL8  2019-05-13 00:00:00      3691.0  2019-05-13 00:00:00
# RBL8  2019-05-14 00:00:00      3742.0  2019-05-16 00:00:00
# RBL8  2019-05-17 00:00:00      3750.0  2019-05-31 00:00:00
# RBL8  2019-06-10 00:00:00      3833.0  2019-06-11 00:00:00
# RBL8  2019-06-13 00:00:00      3755.0  2019-06-14 00:00:00
# RBL8  2019-06-17 00:00:00      3770.0  2019-06-19 00:00:00
# RBL8  2019-06-21 00:00:00      3899.0  2019-07-24 00:00:00

# %%
acc.market_type
# Out:
# 'future_cn'

# %%
risk = QA.QA_Risk(acc)
# Out:
# margin!

# %%
(risk.daily_market_value+ acc.daily_cash.cash).plot()
risk.plot_assets_curve()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
risk.save()
acc.save()
